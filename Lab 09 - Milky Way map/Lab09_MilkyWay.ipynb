# %% [markdown]
# # Lab 9  -  Structure of the Milky Way
#
# In this lab you will look at the positions of star clusters to make a map of the Milky Way! Make sure to read the instructions carefully and answer any written questions within the notebook.
#
#
# Astronomy skills:
# - star clusters
# - galaxy components
#
#
#
# Python skills:
# - sample properties
# - interactive plots

# %% [markdown]
# ## Set up
# Upload the two data files into Colab so you can use them.
#
# Run the cell below to read in the packages you'll need for this lab.

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
# %matplotlib inline

# %% [markdown]
# ## Step 1 - Intro to 3D plots
#
# In this lab, we are going to make interactive, 3D maps of the clusters in our galaxy.
#
#
# Here is an [example for making a 3D scatter plot](https://plotly.com/python/3d-scatter-plots/#basic-3d-scatter-plot) of a helix shape. (Note, we are using the `plotly` package today, instead of `matplotlib`.) Run this cell to see what happens!

# %%
# make arrays of test data
t = np.linspace(0, 10, 50)
xdata = np.cos(t)
ydata = np.sin(t)
zdata = t

# make 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=xdata,
    y=ydata,
    z=zdata,
    mode='markers')])
fig.show()

# %% [markdown]
# Explore your new 3D plot! You don't need to write anything down, but take a few minutes to test out:
# - What happens if you hover your mouse over the data points?
# - What happens if you click and drag the plot around?
# - What happens if you try to zoom in?
# - What do the buttons on the top right do?

# %% [markdown]
# ---
# ## Step 2 - Young star clusters
# 1800s and early 1900's maps of the Milky Way used young star clusters to estimate the galaxy's shape and size. So let's make a 3D map of these young clusters to test it out!

# %% [markdown]
# **Question**:  Which component of the galaxy do the young clusters live in -- the disk, the bulge, or the halo?

# %%
# answer here

#

# %% [markdown]
# The "young_clusters.csv'" file lists the positions of many young star clusters in the Milky Way. The positions are listed relative to the Sun and have 3 components:
# - X (pc) = distance in the direction of the Sun's motion (in the plane of the disk)
# - Y (pc) = distance towards the center of the galaxy  (in the plane of the disk)
# - Z (pc) = distance above the plane of the disk
#
# See the diagram below:

# %% [markdown]
# ![coordinates.png](data:image/png;base64,...)

# %% [markdown]
# First, read in the X, Y, and Z coordinates from the file:

# %%
# read in data

# %% [markdown]
# I started a more customized version of the map plot below, but you need to finish the code.
# - Fill in the `x= `, `y= `, and `z= ` lines with names of your X, Y, and Z arrays.  (e.g., `x=data_x`)
#
# - Run this cell to see the map!

# %%
# Make a 3D scatter plot    * fill in array names here *
fig = go.Figure(data=[go.Scatter3d(
    x= ,
    y= ,
    z= ,
    mode='markers',
    marker=dict(size=3,  opacity=0.6,  color='blue'))])

# change aspect ratio
fig.update_scenes(aspectmode="data")

# show the plot
fig.show()

# %% [markdown]
# **Question**: Based only on this dataset, would you conclude that the Sun is near the center of the galaxy? Why or why not? (Remember, the Sun would be at the origin.)

# %%
# answer here

#

# %% [markdown]
# ---
# ## Step 3 - Old clusters
# In 1918, Shapley made a new map of the Milky Way using old star clusters that are outside the disk of the galaxy.
#
# **Question**:  Which component of the galaxy do the old clusters live in?

# %%
# answer here

#

# %% [markdown]
# Let's make our own 3D map to confirm this!  Repeat Step 2, but this time using old clusters:
# - Read in data from the "old_clusters.csv" file
# - Make a 3D scatter plot of the old cluster positions

# %%
# read in data

# %%
# make a 3D scatter plot

# %% [markdown]
# **Questions**:
# 1. Based only on this dataset, would you conclude that the Sun is near the center of the galaxy?   Why or why not?  (Remember, the Sun is at the origin.)
#
# 2. Why does studying young clusters give us a different map of the Milky Way than studying old clusters? Explain.

# %%
# answer here

# 1.

# 2.

# %% [markdown]
# ## Step 4 - Distance to galactic center

# %% [markdown]
# Let's confirm this by calculating where the center of this dataset is, which will tell you how far the center of the galaxy is from the Sun.
#
# \
#
# Write some code below to calculate the mean value of the old clusters' positions in each direction (X, Y, and Z) and print them out.  Hint: you can use the `np.mean()` function, like this:
# ```
# a = [0, 1, 2, 4, 7, 8]
# mean_a = np.mean(a)
# ```

# %%
# code here

# %% [markdown]
# Then, calculate the total distance from the Sun to the center of the galaxy: $$ d = \sqrt{(mean~x)^2 + (mean~y)^2 + (mean~z)^2}$$

# %%
# code here

# %% [markdown]
# **Question**: How far is the Sun from the center of the galaxy? (Don't forget units!)

# %%
# answer here

#

# %% [markdown]
# ## Step 5 - Size of the Milky Way
#
# We can also use the old clusters to estimate the size of the Milky Way's halo.
#
# Let's just look in the Z direction. If we find the maximum and minimum Z values of the old clusters, then the difference represents the diameter of the Milky Way in the Z direction. Then we can divide by 2 to get the radius of the halo.
#
# Write some code below to calculate:
# - the minimum Z value of the old clusters
# - the maximum Z value of the old clusters
# - the diameter of the halo in the Z direction
# - the radius of the halo in the Z direction

# %%
# code here

# %% [markdown]
# **Question:** What is the radius of the halo? (Don't forget units!)

# %%
# answer here

#

# %% [markdown]
# ---
# ## Bonus [optional]
# How many times farther can we see old clusters compared to young clusters?
#
# Write some code below to:
# - calculate the distances to all the young clusters
#
# - calculate the distances to all the old clusters
#
# - find the farthest young cluster and it's distance
#
# - find the farthest old cluster and it's distance

# %%
# optional code here

# %% [markdown]
# ---
# ## Final steps
#
# **Turning in your lab**
#
# If using Colab -- Click File --> Save a copy to Drive. Save the file to your shared Lab folder.
#
#
# If using Jupyter --
# Save this notebook to your computer, then upload it to your shared Lab folder in Google Drive.
